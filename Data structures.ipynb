# %%
X1=100
X2=50
X1==X2
# Out:
# False

# %%
X1!=X2
# Out:
# True

# %%
X1>X2
# Out:
# True

# %%
X1+X2
# Out:
# 150

# %%
X1<X2
# Out:
# False

# %%
username="xyz"
pwd=123
otp=5541

# %%
username=="xyz" and (pwd==123 or otp==5541)
# Out:
# False

# %%
i=0
i
i=i+2
i
# Out:
# 2

# %%
balance=1000
balance
# Out:
# 1000

# %%
deposit=100
balance=balance+deposit

# %%
balance
# Out:
# 1100

# %%
withdrawn=50
balance=balance-withdrawn

# %%
balance
# Out:
# 1050

# %%
balance-=withdrawn

# %%
balance
# Out:
# 1000

# %%
#DATA STRUCTURES: This concept is completes the data structures where we can store and organize data efficiently so you can perform operations easily. 
# we can assign more than one datatype at a time. python provides several built in data structures:
#@Lists--> List is a data structure ordered and mutable collection(change values) 
#Exmaples present below:

# %%
j1=[500,1000]
j1
# Out:
# [500, 1000]

# %%
type(j1)
# Out:
# list

# %%
j2=[12,15,23,521,41,'Apple',True, 15.22]
j2
# Out:
# [12, 15, 23, 521, 41, 'Apple', True, 15.22]

# %%
type(j2)
# Out:
# list

# %%
j2[4]
# Out:
# 41

# %%
j2[5]
# Out:
# 'Apple'

# %%
len(j2)
# Out:
# 8

# %%
j1.append(18)
j1
# Out:
# [500, 1000, 18]

# %%
j1.pop()
# Out:
# 18

# %%
j2.append(5)

# %%
j2
# Out:
# [12, 15, 23, 521, 41, 'Apple', True, 15.22, 5]

# %%
j2.pop()
# Out:
# 5

# %%
j2.pop(5)
# Out:
# 'Apple'

# %%
j2
# Out:
# [12, 15, 23, 521, 41, True, 15.22]

# %%
j2.insert(0,22)

# %%
j2
# Out:
# [22, 12, 15, 23, 521, 41, True, 15.22]

# %%
j2[6]
# Out:
# True

# %%
j2
# Out:
# [22, 12, 15, 23, 521, 41, True, 15.22]

# %%
j2.remove(15.22)

# %%
j2.remove(True)

# %%
j2
# Out:
# [22, 12, 15, 23, 521, 41]

# %%
j2.insert(1,55)

# %%
j2
# Out:
# [22, 55, 12, 15, 23, 521, 41, 55]

# %%
j2.sort()

# %%
j2
# Out:
# [12, 15, 22, 23, 41, 55, 55, 521]

# %%
# TUPLE is orderd and immutable collection (we cannot change values in it) 
# Examples Syntaxes

# %%
t1=(12,1214,35,40.1,True,'Ramakrishna')

# %%
t1
# Out:
# (12, 12, 14, 35, 40.1, True, 'Ramakrishna', 35)

# %%
type(t1)
# Out:
# tuple

# %%
len(t1)
# Out:
# 8

# %%
t1.count(14)
# Out:
# 1

# %%
t1.index(12)
# Out:
# 0

# %%
t1
# Out:
# (12, 12, 14, 35, 40.1, True, 'Ramakrishna', 35)

# %%
len('rojaramakrishnachikkula')
# Out:
# 23

# %%
# Sets is unorderd and unique elements wont accept duplicate valus
# Examples Syntaxes

# %%
s1={75,14,25,10,68,14,25,19,25,'Ram'}

# %%
s1  #it wont print duplicate values
# Out:
# {10, 14, 19, 25, 68, 75, 'Ram'}

# %%
len(s1)
# Out:
# 7

# %%
# Dictionaories Key_Values pairs to define like with key and value "Name":"Rama" 
# Examples Syntaxes

# %%
d1={"Male":1,"Female":2, "Third Gender":3}

# %%
d1
# Out:
# {'Male': 1, 'Female': 2, 'Third Gender': 3}

# %%
d1.values()
# Out:
# dict_values([1, 2, 3])

# %%
d1.keys()
# Out:
# dict_keys(['Male', 'Female', 'Third Gender'])

# %%
d2={"id":[100,101,102,103], "gender":["M","F","M","F"]}

# %%
d2
# Out:
# {'id': [100, 101, 102, 103], 'gender': ['M', 'F', 'M', 'F']}

# %%
d2.keys()
# Out:
# dict_keys(['id', 'gender'])

# %%
d2.values()
# Out:
# dict_values([[100, 101, 102, 103], ['M', 'F', 'M', 'F']])

# %%
d2["gender"][0]="F"

# %%
d2
# Out:
# {'id': [100, 101, 102, 103], 'gender': ['F', 'F', 'M', 'F']}

# %%
d2.values()
# Out:
# dict_values([[100, 101, 102, 103], ['F', 'F', 'M', 'F']])

# %%
d2["bp"]=[100,120,150,125]

# %%
d2
# Out:
# {'id': [100, 101, 102, 103],
#  'gender': ['F', 'F', 'M', 'F'],
#  'bp': [100, 120, 150, 125]}

# %%
d2["bp"].pop()
# Out:
# 125

# %%
d2
# Out:
# {'id': [100, 101, 102], 'gender': ['F', 'F', 'M'], 'bp': [100, 120, 150]}

# %%
j1=[10,12,32,15,24,35,16,14,"ram"]

# %%
j1
# Out:
# [10, 12, 32, 15, 24, 35, 16, 14, 'ram']

# %%
j1[-1]
# Out:
# 'ram'

# %%
j1
# Out:
# [10, 12, 32, 15, 24, 35, 16, 14, 'ram']

# %%
j1.append(15)

# %%
j1[4:6]
# Out:
# [24, 35]

# %%
j1.index(15)
# Out:
# 3

# %%
j1
# Out:
# [10, 12, 32, 15, 24, 35, 16, 14, 'ram', 15]

# %%
j1.count(15)
# Out:
# 2

# %%
j1.pop()
# Out:
# 15

# %%
j1.insert(2,222)

# %%
j1
# Out:
# [10, 12, 222, 222, 222, 32, 15, 24, 35, 16, 14, 'ram']

# %%
j1.remove(222)

# %%
j1
# Out:
# [10, 12, 222, 222, 32, 15, 24, 35, 16, 14, 'ram']

# %%
j1.pop()
# Out:
# 'ram'

# %%
j1.sort()

# %%
j1
# Out:
# [10, 12, 14, 15, 16, 24, 32, 35, 222, 222]

# %%
j1.sort(reverse=True)

# %%
j1
# Out:
# [222, 222, 35, 32, 24, 16, 15, 14, 12, 10]

# %%
j1.insert(3,44)

# %%
j1=[222, 222, 35, 44, 32, 24, 16, 15, 14, 12, 10, 35, 55, 55, 55]

# %%
j1.clear()

# %%
j1
# Out:
# [222, 222, 35, 44, 32, 24, 16, 15, 14, 12, 10, 35, 55, 55, 55]

# %%
j2=List(j1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 j2=List(j1)
#
# NameError: name 'List' is not defined

# %%
a=[10,12,14,15,16,18,22]

# %%
a.reverse()

# %%
a
# Out:
# [22, 18, 16, 15, 14, 12, 10]

# %%
a.sort()

# %%
empid=[101,102,103,104,105,106,107,108]

# %%
empid
# Out:
# [101, 102, 103, 104, 105, 106, 107, 108]

# %%
empid.reverse()

# %%
empid
# Out:
# [108, 107, 106, 105, 104, 103, 102, 101]

# %%
empid.pop()
# Out:
# 101

# %%
empid.sort()

# %%
empid
# Out:
# [102, 103, 104, 105, 106, 107, 108]

# %%
empid.insert(0,101)

# %%
empid.remove(101)

# %%
empid.insert(0,101)

# %%
empid
# Out:
# [101, 102, 103, 104, 105, 106, 107, 108]

# %%
empid.extend([109,110,111])

# %%
empid
# Out:
# [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111]

# %%
len(empid)
# Out:
# 11
